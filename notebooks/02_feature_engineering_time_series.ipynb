# %% [markdown]
# # Airline Loyalty Intelligence - 02 Feature Engineering & Time Series Aggregations
#
# ## Goal & Objective
# Construct customer-level temporal features, rolling flight statistics, points velocity, and RFM indicators from the cleaned dataset.

# %%
from pathlib import Path
import numpy as np
import pandas as pd

DATA_PROCESSED_DIR = Path('../data/processed')
print("Feature engineering module initialized.")
