# %% [markdown]
# # Airline Loyalty Intelligence - 03 Churn Modeling & SHAP Explainability
#
# ## Goal & Objective
# Train XGBoost / Scikit-Learn classification models to predict airline loyalty churn, evaluate ROC-AUC/F1 metrics, and generate SHAP explainability values for risk scoring.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import xgboost as xgb
import shap
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score

print("Modeling and SHAP explainability environment ready.")
